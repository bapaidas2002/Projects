# %%
import webbrowser

API_KEY = "b181f20a-9100-450f-9ee7-96e6d3594016"          # 👉 Enter your API key
REDIRECT_URI = "http://localhost"     # 👉 Enter your redirect URI (e.g., http://localhost)

auth_url = f"https://api.upstox.com/v2/login/authorization/dialog?response_type=code&client_id={API_KEY}&redirect_uri={REDIRECT_URI}"

print("Open this URL in browser:")
print(auth_url)

webbrowser.open(auth_url)
# Out:
# Open this URL in browser:
# https://api.upstox.com/v2/login/authorization/dialog?response_type=code&client_id=b181f20a-9100-450f-9ee7-96e6d3594016&redirect_uri=http://localhost
# True

# %%
import requests

API_KEY = "b181f20a-9100-450f-9ee7-96e6d3594016"           # 👉 Enter your API key
API_SECRET = "ydh0lbwahb"        # 👉 Enter your API secret
REDIRECT_URI = "http://localhost"      # 👉 Same as above

# 👉 IMPORTANT: After step 1, check your browser's address bar
# You should see: http://127.0.0.1?code=XXXXXXXXXXXXX
# Copy only the code part (XXXXXXXXXXXXX) and paste it below
AUTH_CODE = "CsDThZ"         # 👉 Replace with the code from browser redirect

url = "https://api.upstox.com/v2/login/authorization/token"

payload = {
    "code": AUTH_CODE,
    "client_id": API_KEY,
    "client_secret": API_SECRET,
    "redirect_uri": REDIRECT_URI,
    "grant_type": "authorization_code"
}

headers = {
    "accept": "application/json",
    "Content-Type": "application/x-www-form-urlencoded"
}

response = requests.post(url, data=payload, headers=headers)

data = response.json()

print("\n🔑 Access Token:")
print(data.get("access_token"))

print("\n📦 Full Response:")
print(data)
# Out:
# 🔑 Access Token:
# eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiI3NkI0VEYiLCJqdGkiOiI2OWViMDRlMzBhOWVkODBlMGI1ZDI1MTAiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaXNQbHVzUGxhbiI6dHJ1ZSwiaWF0IjoxNzc3MDA5ODkxLCJpc3MiOiJ1ZGFwaS1nYXRld2F5LXNlcnZpY2UiLCJleHAiOjE3NzcwNjgwMDB9.Abd1QJAPQ6GIdHO_m1Bfq25q0-ZAZtdK8TEftiLj9_c
#
# 📦 Full Response:
# ...

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\HP\Desktop\AMITY\nifty50_historical_6months.csv")
df.head(5)
# Out:
#                         time      open      high       low     close  volume  \
# 0  2025-05-23T15:29:00+05:30  24850.50  24853.20  24842.90  24845.15       0
# 1  2025-05-23T15:28:00+05:30  24855.65  24855.65  24849.55  24853.75       0
# 2  2025-05-23T15:27:00+05:30  24855.00  24856.60  24852.95  24854.55       0
# 3  2025-05-23T15:26:00+05:30  24854.00  24856.05  24852.30  24854.45       0
# 4  2025-05-23T15:25:00+05:30  24852.50  24855.85  24852.00  24853.55       0
#
#    oi
# 0   0
# 1   0
# 2   0
# 3   0
# 4   0
