# %%
#workflow
"""
1.fetch online data using yahoofinace


reference:
1.https://www.sciencedirect.com/science/article/pii/S1877050922020993
2.https://www.nature.com/articles/s41599-024-02807-x
3.https://ijcionline.com/paper/12/12123ijci01.pdf
"""
# Out:
# '\n1.fetch online data using yahoofinace\n\n\nreference:\n1.https://www.sciencedirect.com/science/article/pii/S1877050922020993\n2.https://www.nature.com/articles/s41599-024-02807-x\n3.https://ijcionline.com/paper/12/12123ijci01.pdf\n'

# %%
# %pip install newsapi-python
import yfinance as yf
import pandas as pd
#from newsapi import NewsApiClient
from datetime import datetime, timedelta
# Out:
# ...
#
# ...

# %%
dataset= "RELIANCE.NS"

data = yf.download(dataset, interval="1m", period="1d")

# Use full candle information
data = data[['Open','High','Low','Close','Volume']]

data.dropna(inplace=True)

print(data.tail(10))
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                             Open         High          Low        Close  \
# Ticker                     RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS
# Datetime
# 2026-04-20 04:29:00+00:00  1358.800049  1359.500000  1358.800049  1359.400024
# 2026-04-20 04:30:00+00:00  1359.500000  1359.500000  1359.099976  1359.199951
# 2026-04-20 04:31:00+00:00  1359.199951  1359.199951  1358.300049  1358.599976
# 2026-04-20 04:32:00+00:00  1358.500000  1359.000000  1358.400024  1359.000000
# 2026-04-20 04:33:00+00:00  1359.099976  1360.000000  1359.099976  1359.699951
# 2026-04-20 04:34:00+00:00  1359.800049  1359.800049  1358.800049  1359.099976
# 2026-04-20 04:35:00+00:00  1359.199951  1359.400024  1359.000000  1359.099976
# 2026-04-20 04:36:00+00:00  1359.099976  1359.199951  1358.900024  1359.199951
# 2026-04-20 04:37:00+00:00  1359.199951  1360.099976  1359.199951  1360.099976
# ...
