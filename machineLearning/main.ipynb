# %%
#workflow
"""
1.fetch online data using yahoofinace


reference:
1.https://www.sciencedirect.com/science/article/pii/S1877050922020993
2.https://www.nature.com/articles/s41599-024-02807-x
3.https://ijcionline.com/paper/12/12123ijci01.pdf
"""
# Out:
# '\n1.fetch online data using yahoofinace\n\n\nreference:\n1.https://www.sciencedirect.com/science/article/pii/S1877050922020993\n2.https://www.nature.com/articles/s41599-024-02807-x\n3.https://ijcionline.com/paper/12/12123ijci01.pdf\n'

# %%
# %pip install newsapi-python
import yfinance as yf
import pandas as pd
from newsapi import NewsApiClient
from datetime import datetime, timedelta
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import yfinance as yf
#       2 import pandas as pd
# ----> 3 from newsapi import NewsApiClient
#       4 from datetime import datetime, timedelta
#
# ImportError: cannot import name 'NewsApiClient' from 'newsapi' (C:\Users\HP\AppData\Roaming\Python\Python313\site-packages\newsapi\__init__.py)

# %%
dataset= "RELIANCE.NS"

data = yf.download(dataset, interval="1m", period="1d")

# Use full candle information
data = data[['Open','High','Low','Close','Volume']]

data.dropna(inplace=True)

print(data.tail())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                             Open         High          Low        Close  \
# Ticker                     RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS
# Datetime
# 2026-03-30 09:55:00+00:00  1346.800049  1347.000000  1345.800049  1346.300049
# 2026-03-30 09:56:00+00:00  1346.400024  1347.000000  1346.400024  1346.900024
# 2026-03-30 09:57:00+00:00  1346.800049  1347.000000  1345.099976  1345.199951
# 2026-03-30 09:58:00+00:00  1345.400024  1346.800049  1345.000000  1345.500000
# 2026-03-30 09:59:00+00:00  1346.699951  1355.000000  1346.199951  1350.000000
#
# Price                          Volume
# Ticker                    RELIANCE.NS
# Datetime
# 2026-03-30 09:55:00+00:00      132491
# 2026-03-30 09:56:00+00:00       98053
# 2026-03-30 09:57:00+00:00      172585
# 2026-03-30 09:58:00+00:00       98157
# 2026-03-30 09:59:00+00:00      244175
